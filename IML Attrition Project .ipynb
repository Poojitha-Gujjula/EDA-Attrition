# %% [markdown]
# **Team Members**
#
# Immaneni Harshitha(D22019)
#
# Madduri Uma(D22025)
#
# Gujjula Poojitha(D22033)

# %%
#Importing all the libraries required
import seaborn as sns
import matplotlib.pyplot as plt 
import matplotlib.ticker as mtick
import pandas as pd 
import io

# %%
#Reading the csv file and assigning the data frame
from google.colab import files
uploaded = files.upload()
import io
attrition = pd.read_csv(io.BytesIO(uploaded['attrition.csv']))

# %%
attrition

# %%
#Get the number of rows and columns

attrition.shape
# Out:
# (1470, 20)

# %%
#Column name and data types of all the columns
attrition.dtypes
# Out:
# Age                         int64
# Attrition                   int64
# BusinessTravel             object
# Department                 object
# EducationField             object
# EnvironmentSatisfaction     int64
# Gender                     object
# JobInvolvement              int64
# JobLevel                    int64
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# OverTime                   object
# TotalWorkingYears           int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# DistanceFromHome            int64
# dtype: object

# %%
#Describing categorical variable
attrition.describe(include=['O'])
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            1470                    1470           1470   1470
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             1043                     961            606    882
#
#        MaritalStatus OverTime
# count           1470     1470
# unique             3        2
# top          Married       No
# freq             673     1054

# %%
#To check if there are any null values:

attrition.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# EducationField             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobLevel                   0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# OverTime                   0
# TotalWorkingYears          0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# DistanceFromHome           0
# dtype: int64

# %%
#to check for duplicate values in our data
attrition.duplicated().sum()
# Out:
# 0

# %%
#Describing numeric variables
attrition.describe()
# Out:
#                Age    Attrition  EnvironmentSatisfaction  JobInvolvement  \
# count  1470.000000  1470.000000              1470.000000     1470.000000
# mean     36.923810     0.161224                 2.721769        2.729932
# std       9.135373     0.367863                 1.093082        0.711561
# min      18.000000     0.000000                 1.000000        1.000000
# 25%      30.000000     0.000000                 2.000000        2.000000
# 50%      36.000000     0.000000                 3.000000        3.000000
# 75%      43.000000     0.000000                 4.000000        3.000000
# max      60.000000     1.000000                 4.000000        4.000000
#
#           JobLevel  JobSatisfaction  MonthlyIncome  TotalWorkingYears  \
# count  1470.000000      1470.000000    1470.000000        1470.000000
# mean      2.063946         2.728571    6502.931293          11.279592
# std       1.106940         1.102846    4707.956783           7.780782
# ...

# %% [markdown]
# **OBSERVATION:**
#
# 1. Attrition has value either 0 or 1. 0 being no attrition and 1 being attrition
# 2.We know that there are no null values in the data set.So we dont have to go for Imputation
# 3.There are no duplicates in the dataset
# 4.There are 1470 entries and 20 columns
# 5.There ae 14 integer columns and 6 object type columns.We know the values for all the categircal columns.
# 6.Avg monthly income is 6500 but median is 4919 so the monthly income is skewed
# 7.People have a work experiance of 11 years on avg
# 8.There are more married male who dont do overtime

# %% [markdown]
# **Univariate Analysis**

# %% [markdown]
# Distribution of all Numeric Variables:

# %%
#Lets plot univariate distribution of all the numeric variables
fig, axes = plt.subplots(4, 4, figsize=(20, 15))
sns.distplot(attrition['Age'], kde=True,ax=axes[0,0])
sns.distplot(attrition['Attrition'], kde=True,ax=axes[0,1])
sns.distplot(attrition['EnvironmentSatisfaction'], kde=False,ax=axes[0,2])
sns.distplot(attrition['JobInvolvement'], kde=False,ax=axes[0,3])
sns.distplot(attrition['JobLevel'], kde=False,ax=axes[1,0])
sns.distplot(attrition['JobSatisfaction'], kde=False,ax=axes[1,1])
sns.distplot(attrition['MonthlyIncome'], kde=True,ax=axes[1,2])
sns.distplot(attrition['TotalWorkingYears'], kde=True,ax=axes[1,3])
sns.distplot(attrition['WorkLifeBalance'], kde=False,ax=axes[2,0])
sns.distplot(attrition['YearsAtCompany'], kde=True,ax=axes[2,1])
sns.distplot(attrition['YearsInCurrentRole'], kde=True,ax=axes[2,2])
sns.distplot(attrition['YearsSinceLastPromotion'], kde=True,ax=axes[2,3])
sns.distplot(attrition['DistanceFromHome'], kde=True,ax=axes[3,0])
#sns.relplot(x="DistanceFromHome",hue="smoker", data=attrition_data);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **Insights from above plots**
#
# 1.Most of the employees recently got promoted.
#
# 2.Most of the employees worked for 5 years at their job role.
#
# 3.Most of the employees stay near the office.
#
# 4.Most of the employees spend upto 10 years in the company.
#
# 5.Most of the employees are at the job level 1 and job level 2. And this could be the reason for the less salaries.
#
# 6.Most of the employees get the less salary.
#
# 7.Job satisfaction for most of the employees is high and this could be the reason for the good job involvement(mostly it is 3 out of 5).

# %%
#Analysing the attrition value 0 and 1
attrition.groupby('Attrition').size().plot(kind='pie', autopct='%.2f')
plt.title('Attrition Breakup',fontsize=14)
plt.show()
attrition.groupby('Attrition')['Attrition'].count().plot(kind='bar',rot=0)
plt.show()

# %% [markdown]
# **Insights**
# 1. Binary data and Ordinal Scale.
# 2. 1-Left thye company and 0-still in the company
#
# Q: How many employees left?
#
# A: 237(which is 16.12%) employees left out of 1470

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
#for categorical variables we will analyze all attributes relation with attrition through visualisation in bivariate

attrition[['Gender','Attrition']].groupby(['Gender']).mean()
# Out:
#         Attrition
# Gender
# Female   0.147959
# Male     0.170068

# %%
plt.subplots (figsize=(8,4))
sns.countplot (x='Gender',  hue='Attrition', data= attrition, color = 'cyan')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# Attrition Rate is higher in males

# %%
attrition['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# % of employee in these categories to study the company travel behaviour?
# Travel Rarely : 71% (1043),
# Travel Frequently : 19% (277),
# Non-Travel : 10% (150)

# %%
#Attrition Rate with respect to Business Travel:
plt.subplots (figsize=(8,4))
sns.countplot (x='BusinessTravel',  hue='Attrition', data= attrition, color = 'red')
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# Attrition rate is higher in the employees who rarely travel.
# So we can conclude that travelling of the employees is not effecting the attrition.

# %%
#Attrition rate with respect to Department:
plt.subplots (figsize=(8,4))
sns.countplot (x='Department',  hue='Attrition', data= attrition, color = 'green')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# Attrition Rate is higher in Research and Development Department

# %%
#Attrition rate with respect to Age:
plt.subplots (figsize=(14,7))
sns.countplot (x='Age',  hue='Attrition', data= attrition, color = 'black')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# Attrition Rate is higher in the employees whose age groung is between mid 20's and mid30's.

# %%
#Education Field breakup:

attrition.groupby('EducationField').size().plot(kind='pie', autopct='%.2f')
plt.title('EducationField breakup',fontsize=14)
plt.show()

# %%
#Education field with respect to attrition:
plt.subplots (figsize=(14,7))
sns.countplot (x='EducationField',  hue='Attrition', data= attrition, color = 'purple')
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# Attrition Rate is high in the employees whose Educational background is Life Sciences

# %%
#Overtime breakup:

attrition.groupby('OverTime').size().plot(kind='pie', autopct='%.2f')
plt.title('OverTime breakup',fontsize=14)
plt.show()

# %%
#Overtime with respect to attrition:
plt.subplots (figsize=(9,7))
sns.countplot (x='OverTime',  hue='Attrition', data= attrition, color = 'blue')
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# Attrition rate is high among the employees who work for overtime

# %% [markdown]
# **CONCLUSION**
#
# We could see that the below factors are affecting the attrition among the ones on which the bivariate analysis is performed:
#
# 1.Gender
#
# 2.Department
#
# 3.Age
#
# 4.Education

# %% [markdown]
# **MULTIVARIATE ANALYSIS**
#
# 1. Lets consider **MaritalStatus** affecting the attrition

# %%
plt.figure(figsize=(4,4))
sns.catplot(x='MaritalStatus',y='Age',hue='Attrition',kind='swarm',data=attrition)
sns.catplot(x='MaritalStatus',y='MonthlyIncome',hue='Attrition',kind='swarm',data=attrition)
sns.catplot(x='MaritalStatus',y='JobLevel',hue='Attrition',kind='swarm',data=attrition)
sns.catplot(x='MaritalStatus',y='TotalWorkingYears',hue='Attrition',kind='swarm',data=attrition)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 28.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 5.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 23.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# **Insights**
#
# 1.People who are more likely to quit are Single with lower income <5000
# 2.People at joblevel 1 and single tend to quit after 1 year work experience because they are ready to take risk.

# %% [markdown]
# 1. Lets consider **TotalWorkingYears** affecting the attrition

# %%
plt.subplots(figsize=(12,4))
factor1 = sns.countplot(x="TotalWorkingYears", hue="Attrition", data=attrition)

# %%
attrition[["Attrition","TotalWorkingYears"]].groupby(["Attrition"]).describe()
# Out:
#           TotalWorkingYears
#                       count       mean       std  min  25%   50%   75%   max
# Attrition
# 0                    1233.0  11.862936  7.760719  0.0  6.0  10.0  16.0  38.0
# 1                     237.0   8.244726  7.169204  0.0  3.0   7.0  10.0  40.0

# %%
plt.figure(figsize=(4,4))
sns.lmplot(x='TotalWorkingYears',y='Age',hue='Attrition',fit_reg=False,data=attrition)
sns.catplot(y='TotalWorkingYears',x='JobLevel',hue='Attrition',kind="swarm",data=attrition)
sns.lmplot(x='TotalWorkingYears',y='MonthlyIncome',hue='Attrition',fit_reg=False,data=attrition)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 72.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 71.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 35.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 12.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# **Insights**
# 1.This is as expected as total working years increases -job level ,monthly income and age increases.People like changing jobs at lower job level ,at young age and when they have lower salary

# %% [markdown]
# Lets consider a **hypothesis** and see which factors are affecting the attrition the most:

# %% [markdown]
# 1.BusinessTravel
#
# 2.OverTime
#
# 3.MaritalStatus
#
# 4.WorkLifeBalance
#
# 5.EducationField

# %% [markdown]
# **Finding the correlation**

# %%
corr = attrition.corr()

# %%
print (corr['Attrition'].sort_values(ascending=True), '\n')
# Out:
# TotalWorkingYears         -0.171063
# JobLevel                  -0.169105
# YearsInCurrentRole        -0.160545
# MonthlyIncome             -0.159840
# Age                       -0.159205
# YearsWithCurrManager      -0.156199
# YearsAtCompany            -0.134392
# JobInvolvement            -0.130016
# JobSatisfaction           -0.103481
# EnvironmentSatisfaction   -0.103369
# WorkLifeBalance           -0.063939
# YearsSinceLastPromotion   -0.033019
# DistanceFromHome           0.077924
# Attrition                  1.000000
# Name: Attrition, dtype: float64

# %% [markdown]
# **Crameres V method**

# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import seaborn as sns
#tips = sns.load_dataset("attrition.csv")
def cramers_v(confusion_matrix):
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# %%
confusion_matrix_businessTravel = pd.crosstab(attrition["Attrition"],attrition["BusinessTravel"]).values
confusion_matrix_Overtime = pd.crosstab(attrition["Attrition"],attrition["OverTime"]).values
confusion_matrix_marital_status = pd.crosstab(attrition["Attrition"],attrition["MaritalStatus"]).values
confusion_matrix_WorkLifeBalance = pd.crosstab(attrition["Attrition"],attrition["WorkLifeBalance"]).values
confusion_matrix_EducationField = pd.crosstab(attrition["Attrition"],attrition["EducationField"]).values

# %% [markdown]
# Lets Add the categorical corelation to our correlation matrix and then sort all the correlation in descending order

# %%
corr['Attrition']['BusinessTravel'] = cramers_v(confusion_matrix_businessTravel)
corr['Attrition']['OverTime'] = cramers_v(confusion_matrix_Overtime)
corr['Attrition']['MaritalStatus'] = cramers_v(confusion_matrix_marital_status)
corr['Attrition']['WorkLifeBalance'] = cramers_v(confusion_matrix_WorkLifeBalance)
corr['Attrition']['EducationField'] = cramers_v(confusion_matrix_EducationField)
print (abs(corr['Attrition']).sort_values(ascending=False), '\n')
# Out:
# Attrition                  1.000000
# TotalWorkingYears          0.171063
# JobLevel                   0.169105
# YearsInCurrentRole         0.160545
# MonthlyIncome              0.159840
# Age                        0.159205
# YearsWithCurrManager       0.156199
# YearsAtCompany             0.134392
# JobInvolvement             0.130016
# JobSatisfaction            0.103481
# EnvironmentSatisfaction    0.103369
# WorkLifeBalance            0.095234
# DistanceFromHome           0.077924
# YearsSinceLastPromotion    0.033019
# Name: Attrition, dtype: float64

# %% [markdown]
# Used this library for finding all types of correlation together in a single heatmap (also used this method to confirm if both methods of finding correlations are giving same answers)
# This method uses
# <b>Pearsons R</b> for continuous vs continuous cases
# <b>Correlation ratio</b> for categorical vs continuous
# <b>Cramers V</b> for categorical vs categorical

# %%
pip install dython
# Out:
# ...
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.8.0
#     Uninstalling psutil-5.8.0:
#       Successfully uninstalled psutil-5.8.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.

# %%
from dython import nominal
nominal.associations(attrition[['OverTime','Attrition','Age','JobSatisfaction','BusinessTravel','DistanceFromHome','JobInvolvement','JobLevel',
                          'MaritalStatus','MonthlyIncome','TotalWorkingYears','WorkLifeBalance','YearsAtCompany',
                          'YearsInCurrentRole']],figsize=(17,13))
# Out:
# {'corr':                     OverTime  Attrition       Age  JobSatisfaction  \
#  OverTime            1.000000   0.246118  0.028062         0.024539
#  Attrition           0.246118   1.000000 -0.159205        -0.103481
#  Age                 0.028062  -0.159205  1.000000        -0.004892
#  JobSatisfaction     0.024539  -0.103481 -0.004892         1.000000
#  BusinessTravel      0.024089   0.128260  0.029165         0.036567
#  DistanceFromHome    0.025514   0.077924 -0.001686        -0.003669
#  JobInvolvement      0.003507  -0.130016  0.029820        -0.021476
#  JobLevel            0.000544  -0.169105  0.509604        -0.001944
#  MaritalStatus       0.000000   0.177211  0.119727         0.025455
#  MonthlyIncome       0.006089  -0.159840  0.497855        -0.007157
#  TotalWorkingYears   0.012754  -0.171063  0.680381        -0.020185
#  WorkLifeBalance     0.027092  -0.063939 -0.021490        -0.019459
#  YearsAtCompany      0.011687  -0.134392  0.311309        -0.003803
# ...
